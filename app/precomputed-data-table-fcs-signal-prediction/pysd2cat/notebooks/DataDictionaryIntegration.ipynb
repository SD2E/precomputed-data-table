# %%
from pysd2cat.data import data_dictionary as dd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e128de586716> in <module>
# ----> 1 from pysd2cat.data import data_dictionary as dd
#
# ~/Documents/sift/xplan/external/xplan/xplan-to-autoprotocol-reactor/xplan-dev-env/pysd2cat/src/pysd2cat/data/data_dictionary.py in <module>
# ----> 1 from sbol import *
#       2 from synbiohub_adapter.query_synbiohub import *
#       3 from synbiohub_adapter.SynBioHubUtil import *
#       4 from synbiohub_adapter.SynBioHubUtil import SD2Constants
#       5
#
# ModuleNotFoundError: No module named 'sbol'

# %%
from sbol import *
from synbiohub_adapter.query_synbiohub import *
from synbiohub_adapter.SynBioHubUtil import *
from synbiohub_adapter.SynBioHubUtil import SD2Constants

def get_sbh_query():
    sbh_query = SynBioHubQuery(SD2Constants.SD2_SERVER)
    sbh_query.login("sd2e", "jWJ1yztJl2f7RaePHMtXmxBBHwNt")
    return sbh_query

def get_uri_handle(uri):
    sbh_query = get_sbh_query()
    # Are we parsing a URI directly, not an internal lab id?
    query ="""PREFIX sbol: <http://sbols.org/v2#>
    PREFIX dcterms: <http://purl.org/dc/terms/>
    PREFIX sd2: <http://sd2e.org#>
    SELECT ?id WHERE {{
        <https://hub.sd2e.org/user/sd2e/design/design_collection/1> sbol:member ?identity .
        # ?identity <http://sd2e.org#Transcriptic_UID> ?id 
    }}""".format(uri)

    designs = sbh_query.fetch_SPARQL(SD2Constants.SD2_SERVER, query)

    # format return
    designs = sbh_query.format_query_result(designs, ['id'])
    return designs

# %%
# URI
uri = "https://hub.sd2e.org/user/sd2e/design/CEN0x2EPK20x200x2D0x20MAT0x20A/1"
get_uri_handle(uri)
# Out:
# ['16967',
#  '5783',
#  '7300',
#  '7374',
#  '8542',
#  '16970',
#  '152641',
#  '8544',
#  'rs1b8cybgdd7gz',
#  'MG1655_PhlF_Gate',
#  'MG1655_NAND_Circuit',
#  'MG1655_pTACmin',
#  'MG1655_IcaR_Gate',
#  'MG1655_WT',
#  'rs1bcj2388xppe',
#  'rs1bmsy53j23pj',
#  'rs1bmsyy3wx39v',
#  'rs1bb2m7vfknh9',
#  'rs19e9hd7xb8n3',
#  'MG1655_pBADmin',
#  'MG1655_pJS007_LALT__backbone',
#  'MG1655_pJS007_LALT__P3__PhlF',
#  'MG1655_pJS007_LALT__I1__IcaRA',
#  'IPTG',
#  'rs18vwgfgxq597',
#  'Arabinose',
#  'rs1apwddkptp5q',
#  'SizeBeadControl',
#  'BY4741_Colony_2_Day_1',
#  'BY4741_Colony_2_Day_2',
#  'BY4741_Colony_4_Day_2',
#  'BY4741_Colony_4_Day_1',
#  'BY4741_Colony_1_Day_1',
#  'BY4741_Colony_1_Day_2',
#  'BY4741_Colony_3_Day_2',
#  'BY4741_Colony_3_Day_1',
#  'CYE72_Colony_2_Day_2',
#  'CYE72_Colony_2_Day_1',
#  'CYE72_Colony_4_Day_2',
#  'CYE72_Colony_4_Day_1',
#  'CYE72_Colony_1_Day_1',
#  'CYE72_Colony_1_Day_2',
#  'CYE72_Colony_3_Day_2',
#  'CYE72_Colony_3_Day_1',
#  'CY637int_Colony_3_Day_2',
#  'CY637int_Colony_3_Day_1',
#  'CY637int_Colony_1_Day_2',
#  'CY637int_Colony_1_Day_1',
#  'CY637int_Colony_2_Day_2',
#  'CY637int_Colony_2_Day_1',
#  'CY637int_Colony_4_Day_2',
#  'CY637int_Colony_4_Day_1',
#  'CY638int_Colony_2_Day_1',
#  'CY638int_Colony_2_Day_2',
#  'CY638int_Colony_4_Day_2',
#  'CY638int_Colony_4_Day_1',
#  'CY638int_Colony_1_Day_1',
#  'CY638int_Colony_1_Day_2',
#  'CY638int_Colony_3_Day_2',
#  'CY638int_Colony_3_Day_1',
#  'CY928int_Colony_3_Day_2',
#  'CY928int_Colony_3_Day_1',
#  'CY928int_Colony_1_Day_2',
#  'CY928int_Colony_1_Day_1',
#  'CY928int_Colony_2_Day_2',
#  'CY928int_Colony_2_Day_1',
#  'CY928int_Colony_4_Day_2',
#  'CY928int_Colony_4_Day_1',
#  'CY671int_Colony_2_Day_2',
#  'CY671int_Colony_2_Day_1',
#  'CY671int_Colony_4_Day_2',
#  'CY671int_Colony_4_Day_1',
#  'CY671int_Colony_1_Day_1',
#  'CY671int_Colony_1_Day_2',
#  'CY671int_Colony_3_Day_2',
#  'CY671int_Colony_3_Day_1',
#  'CY960-CY663int_Colony_3_Day_2',
#  'CY960-CY663int_Colony_3_Day_1',
#  'CY960-CY663int_Colony_1_Day_2',
#  'CY960-CY663int_Colony_1_Day_1',
#  'CY960-CY663int_Colony_2_Day_2',
#  'CY960-CY663int_Colony_2_Day_1',
#  'CY960-CY663int_Colony_4_Day_2',
#  'CY960-CY663int_Colony_4_Day_1',
#  'CY963-CY609int_Colony_3_Day_1',
#  'CY963-CY609int_Colony_3_Day_2',
#  'CY963-CY609int_Colony_1_Day_1',
#  'CY963-CY609int_Colony_1_Day_2',
#  'CY963-CY609int_Colony_4_Day_2',
#  'CY963-CY609int_Colony_2_Day_2',
#  'CY963-CY609int_Colony_2_Day_1',
#  'CY963-CY609int_Colony_4_Day_1',
#  'CY965-CY668int_Colony_3_Day_1',
#  'CY965-CY668int_Colony_3_Day_2',
#  'CY965-CY668int_Colony_1_Day_1',
#  'CY965-CY668int_Colony_1_Day_2',
#  'CY965-CY668int_Colony_4_Day_2',
#  'CY965-CY668int_Colony_2_Day_2',
#  'CY965-CY668int_Colony_2_Day_1',
#  'CY965-CY668int_Colony_4_Day_1',
#  'CY966-CY653int_Colony_3_Day_1',
#  'CY966-CY653int_Colony_3_Day_2',
#  'CY966-CY653int_Colony_1_Day_1',
#  'CY966-CY653int_Colony_1_Day_2',
#  'CY966-CY653int_Colony_4_Day_2',
#  'CY966-CY653int_Colony_4_Day_1',
#  'CY966-CY653int_Colony_2_Day_1',
#  'CY966-CY653int_Colony_2_Day_2',
#  'CY968-CY661int_Colony_3_Day_2',
#  'CY968-CY661int_Colony_3_Day_1',
#  'CY968-CY661int_Colony_1_Day_2',
#  'CY968-CY661int_Colony_1_Day_1',
#  'CY968-CY661int_Colony_2_Day_2',
#  'CY968-CY661int_Colony_2_Day_1',
#  'CY968-CY661int_Colony_4_Day_2',
#  'CY968-CY661int_Colony_4_Day_1',
#  'CY968-CY662int_Colony_3_Day_2',
#  'CY968-CY662int_Colony_3_Day_1',
#  'CY968-CY662int_Colony_1_Day_2',
#  'CY968-CY662int_Colony_1_Day_1',
#  'CY968-CY662int_Colony_2_Day_2',
#  'CY968-CY662int_Colony_2_Day_1',
#  'CY968-CY662int_Colony_4_Day_2',
#  'CY968-CY662int_Colony_4_Day_1',
#  'CYx16-CY658int_Colony_3_Day_2',
#  'CYx16-CY658int_Colony_3_Day_1',
#  'CYx16-CY658int_Colony_1_Day_2',
#  'CYx16-CY658int_Colony_1_Day_1',
#  'CYx16-CY658int_Colony_2_Day_2',
#  'CYx16-CY658int_Colony_2_Day_1',
#  'CYx16-CY658int_Colony_4_Day_2',
#  'CYx16-CY658int_Colony_4_Day_1',
#  'CYx16-CY660int_Colony_1_Day_1',
#  'CYx16-CY660int_Colony_1_Day_2',
#  'CYx16-CY660int_Colony_3_Day_2',
#  'CYx16-CY660int_Colony_3_Day_1',
#  'CYx16-CY660int_Colony_4_Day_2',
#  'CYx16-CY660int_Colony_4_Day_1',
#  'CYx16-CY660int_Colony_2_Day_1',
#  'CYx16-CY660int_Colony_2_Day_2',
#  'CY970-CY660int_Colony_2_Day_1',
#  'CY970-CY660int_Colony_2_Day_2',
#  'CY970-CY660int_Colony_4_Day_2',
#  'CY970-CY660int_Colony_4_Day_1',
#  'CY970-CY660int_Colony_1_Day_1',
#  'CY970-CY660int_Colony_1_Day_2',
#  'CY970-CY660int_Colony_3_Day_2',
#  'CY970-CY660int_Colony_3_Day_1',
#  'CY974-CY952int_Colony_3_Day_2',
#  'CY974-CY952int_Colony_3_Day_1',
#  'CY974-CY952int_Colony_1_Day_2',
#  'CY974-CY952int_Colony_1_Day_1',
#  'CY974-CY952int_Colony_2_Day_2',
#  'CY974-CY952int_Colony_2_Day_1',
#  'CY974-CY952int_Colony_4_Day_2',
#  'CY974-CY952int_Colony_4_Day_1',
#  'CY974-CY953int_Colony_1_Day_1',
#  'CY974-CY953int_Colony_1_Day_2',
#  'CY974-CY953int_Colony_3_Day_2',
#  'CY974-CY953int_Colony_3_Day_1',
#  'CY974-CY953int_Colony_4_Day_2',
#  'CY974-CY953int_Colony_4_Day_1',
#  'CY974-CY953int_Colony_2_Day_1',
#  'CY974-CY953int_Colony_2_Day_2',
#  'CYx76-CYx40int_Colony_2_Day_1',
#  'CYx76-CYx40int_Colony_2_Day_2',
#  'CYx76-CYx40int_Colony_4_Day_2',
#  'CYx76-CYx40int_Colony_4_Day_1',
#  'CYx76-CYx40int_Colony_1_Day_1',
#  'CYx76-CYx40int_Colony_1_Day_2',
#  'CYx76-CYx40int_Colony_3_Day_2',
#  'CYx76-CYx40int_Colony_3_Day_1',
#  'CYx19-CY948int_Colony_3_Day_2',
#  'CYx19-CY948int_Colony_3_Day_1',
#  'CYx19-CY948int_Colony_1_Day_2',
#  'CYx19-CY948int_Colony_1_Day_1',
#  'CYx19-CY948int_Colony_4_Day_1',
#  'CYx19-CY948int_Colony_4_Day_2',
#  'CYx19-CY948int_Colony_2_Day_2',
#  'CYx19-CY948int_Colony_2_Day_1',
#  '5993',
#  '7373',
#  '7376',
#  '16969',
#  'rs1bb2mbzqz9py',
#  'rs1bb2mf8gu6k5',
#  'W303dip1',
#  '5992',
#  '6389',
#  '6390',
#  '6391',
#  '8231',
#  '8545',
#  'rs1b4uj7zbdy6m',
#  'rs1b6z2vgatkq7',
#  '6388',
#  '7299',
#  '7375',
#  '7377',
#  '8225',
#  '8543',
#  '16968',
#  'rs1b9eweedsc7p',
#  'rs1b6z2vgatkq7',
#  'rs1bga86uq52tz',
#  'rs1apwazmvzbqy']
