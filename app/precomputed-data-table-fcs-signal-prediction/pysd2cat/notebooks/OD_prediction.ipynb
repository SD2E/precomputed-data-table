# %%
import os
import sys
import pandas as pd
from os.path import expanduser
import numpy as np
        
from  pysd2cat.analysis import od_predictor

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7b5f2a70c774> in <module>
#       5 import numpy as np
#       6
# ----> 7 from  pysd2cat.analysis import od_predictor
#       8
#       9 get_ipython().run_line_magic('load_ext', 'autoreload')
#
# ModuleNotFoundError: No module named 'pysd2cat'

# %%
df1 = pd.read_csv(os.path.join(os.getcwd(), '../resources/tx_od.csv'), index_col=0)
#df1.loc[:, 'inc_time_2'] = df1.apply(lambda x: float(x['inc_time_2'].split(":")[0]), axis=1)
#df1.loc[:, 'inc_time_1'] = df1.apply(lambda x: float(x['inc_time_1'].split(":")[0]), axis=1)
#df1.loc[:, 'inc_temp'] = df1.apply(lambda x: float(x['inc_temp'].split("_")[1]), axis=1)
df1

# %%
#df1.loc[:,'post_od_raw_obs'] = df1['post_od_raw']
targets=[0.05, 0.1, 0.25, 0.5, 1.0]
duration = "8:hour"


dfp = pd.DataFrame({'SynBioHub URI' : df1['SynBioHub URI'].unique()})
dfp.loc[:, 'inc_time_1'] = 18
dfp.loc[:, 'inc_time_2'] = duration
dfp.loc[:, 'growth_media_1'] = 'standard_media'
dfp.loc[:, 'growth_media_2'] = 'standard_media'
dfp.loc[:, 'inc_temp'] = "warm_30"
dfp.loc[:, 'od'] = 0

dfp.loc[:,'key'] = 0 
fdf = pd.DataFrame({'post_od_raw' : targets})
fdf.loc[:,'key'] = 0
dfp = dfp.merge(fdf, how='left', on='key').drop(columns=['key'])

# %%
# Actual Data

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

strains = df1['SynBioHub URI'].unique()

data=df1.loc[df1['inc_time_2'] == duration]

#for target in targets:
#    plt.axhline(target)
    
for strain in strains:
    p = data.loc[data['SynBioHub URI'] == strain]
    p = p.sort_values(['od'], ascending=True)
    plt.plot(p['od'], p['post_od_raw'], label=strain,alpha=0.5);


#    s = predictions.loc[(predictions['SynBioHub URI'] == strain)  ]
#    s = s.sort_values(['post_od_raw'], ascending=True)
#    plt.plot(s['od_predictions'], s['post_od_raw'], label=None,  marker='x', alpha=0.5);

    
    
    #plt.legend()
plt.xscale('log')
#plt.yscale('log')
plt.xlabel("Inoculation OD")
plt.ylabel("Post OD")

plt.title(str(duration) + "h Actual Post OD")

# %%
predictions = od_predictor.predict(df1, dfp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

strains = df1['SynBioHub URI'].unique()

data=df1.loc[df1['inc_time_2'] == duration]

for target in targets:
    plt.axhline(target)
    
for strain in strains:
    p = data.loc[data['SynBioHub URI'] == strain]
    p = p.sort_values(['od'], ascending=True)
    plt.plot(p['od'], p['post_od_raw'], label=strain,alpha=0.1);


    s = predictions.loc[(predictions['SynBioHub URI'] == strain)  ]
    s = s.sort_values(['post_od_raw'], ascending=True)
    plt.plot(s['od_predictions'], s['post_od_raw'], label=None,  marker='x', alpha=0.5);

    
    
    #plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Inoculation OD")
plt.ylabel("Post OD")
plt.title(str(duration) + "h Predicted Post OD = " + str(target))

# %%
from pysd2cat.analysis.doubling_time import find_time_of_increase, doubling_time, exp_func
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

df = pd.read_csv(os.path.join(os.getcwd(), '../resources/tx_od.csv'), index_col=0, dtype={'input': object})
df.loc[:, 'inc_time_2'] = df.apply(lambda x: float(x['inc_time_2'].split(":")[0]), axis=1)
df.loc[:, 'inc_time_1'] = df.apply(lambda x: float(x['inc_time_1'].split(":")[0]), axis=1)
df.loc[:, 'inc_temp'] = df.apply(lambda x: float(x['inc_temp'].split("_")[1]), axis=1)

y_value = 'post_od_raw'
x_value = 'inc_time_2'
grouping = ['SynBioHub URI', 'od', 'media', 'inc_temp']


groups = df.groupby(grouping)
#groups.first()
doubling_times = pd.DataFrame()
for k, group in groups:
    #print(k)
    group = group.groupby(x_value).mean().reset_index()
    #print(group)
    if len(group) < 3:
        continue
        
    group = group.sort_values(by=x_value)
    #print(group[[x_value, y_value]])
#    try:
#        time_of_increase, cond_well_df = find_time_of_increase(group, y_value, 
#                                                               window = 1, time_col=x_value)
#    except Exception as e:
#        time_of_increase = group[x_value].iloc[0]
#        cond_well_df = group
#    #print("Time of increase = " + str(time_of_increase))
#    increasing_df = cond_well_df.loc[cond_well_df[x_value] >= time_of_increase]
    
#    if len(increasing_df) < 2:
#        continue
    
    try:
#        (time_points,y_vals,popt,pcov) = doubling_time(increasing_df, y_value, time_col=x_value)
        (time_points,y_vals,popt,pcov) = doubling_time(group, y_value, time_col=x_value)
    except Exception as e:
        print(e)
        #print(increasing_df[[x_value, y_value]])
    
    #print(increasing_df[[x_value, y_value, 'moving_average']])
#    print(popt)
    #print(time_points)
    #print(y_vals)
#    (time_points,y_vals,popt,pcov) = doubling_time(group, "y_value", time_col=x_value)
    #plt.plot(group[x_value], cond_well_df["moving_average"], label='mv av')
#    plt.plot(group[x_value], group[y_value], label='actual')
    #plt.axvline(time_of_increase, label='increase')
#    plt.plot(time_points, y_vals, label='fit')
#    plt.legend()
    #plt.xscale('log')
    #plt.yscale('log')
    row = dict(zip(grouping + ['doubling_time', 'inc_time_2'], 
                   list(k) + [popt[1]] + [group[x_value]]))
    doubling_times = doubling_times.append(row, ignore_index=True)
#    break
#doubling_times

# %%
doubling_times.loc[doubling_times['doubling_time'] > 10.0]
#doubling_times
# Out:
#                                         SynBioHub URI  doubling_time  inc_temp                                                                                    inc_time_2           media       od
# 99  https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1  12.962506      30.0      0    8.0
# 1    10.0
# 2    12.0
# 3    15.0
# 4    16.0
# 5    18.0
# Name: inc_time_2, dtype: float64  standard_media  0.00002

# %%
doubling_variance = doubling_times.groupby(['SynBioHub URI', 'media', 'inc_temp']).agg( [np.mean, np.median, np.std]).drop(columns=['od']).reset_index() 
doubling_variance.columns = doubling_variance.columns = [ "_".join(x) if x[1] != '' else x[0] for x in doubling_variance.columns.ravel()]
#print(doubling_variance.columns.ravel())
#print(df.dtypes)
doubling_variance = doubling_variance.merge(df[['SynBioHub URI', 'strain_circuit', 'input']].drop_duplicates(), on='SynBioHub URI', how='left')
doubling_variance = doubling_variance.drop(columns=[ 'media', 'inc_temp'])
doubling_variance = doubling_variance.sort_values(by='doubling_time_median', ascending=True)



targets=[0.1, 0.5, 1.0, 1.5, 2.0]
doubling_target = doubling_variance.copy()

doubling_target.loc[:,'key'] = 0 
fdf = pd.DataFrame({'post_od_raw' : targets})
fdf.loc[:,'key'] = 0
doubling_target = doubling_target.merge(fdf, how='left', on='key').drop(columns=['key'])

doubling_target.loc[:,'od'] = doubling_target.apply(lambda x: x['post_od_raw']/np.exp2(8.0 / x['doubling_time_mean']), axis=1)
doubling_target
# Out:
#                                           SynBioHub URI  doubling_time_mean  doubling_time_median  doubling_time_std strain_circuit input  post_od_raw        od
# 0    https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1   2.234388            2.231629              0.575075           NAND           00    0.1          0.008360
# 1    https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1   2.234388            2.231629              0.575075           NAND           00    0.5          0.041799
# 2    https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1   2.234388            2.231629              0.575075           NAND           00    1.0          0.083597
# 3    https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1   2.234388            2.231629              0.575075           NAND           00    1.5          0.125396
# 4    https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1   2.234388            2.231629              0.575075           NAND           00    2.0          0.167195
# 5    https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1   2.555079            2.459933              0.969249           OR             00    0.1          0.011415
# 6    https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1   2.555079            2.459933              0.969249           OR             00    0.5          0.057074
# 7    https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1   2.555079            2.459933              0.969249           OR             00    1.0          0.114148
# 8    https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1   2.555079            2.459933              0.969249           OR             00    1.5          0.171223
# 9    https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1   2.555079            2.459933              0.969249           OR             00    2.0          0.228297
# 10   https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1   2.657895            2.631736              0.582340           OR             10    0.1          0.012415
# 11   https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1   2.657895            2.631736              0.582340           OR             10    0.5          0.062073
# 12   https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1   2.657895            2.631736              0.582340           OR             10    1.0          0.124145
# 13   https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1   2.657895            2.631736              0.582340           OR             10    1.5          0.186218
# 14   https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1   2.657895            2.631736              0.582340           OR             10    2.0          0.248290
# 15   https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1   2.305241            2.665238              0.736464           XNOR           10    0.1          0.009022
# 16   https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1   2.305241            2.665238              0.736464           XNOR           10    0.5          0.045112
# 17   https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1   2.305241            2.665238              0.736464           XNOR           10    1.0          0.090224
# 18   https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1   2.305241            2.665238              0.736464           XNOR           10    1.5          0.135335
# 19   https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1   2.305241            2.665238              0.736464           XNOR           10    2.0          0.180447
# 20   https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1   2.786551            2.670592              1.917763           AND            01    0.1          0.013670
# 21   https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1   2.786551            2.670592              1.917763           AND            01    0.5          0.068349
# 22   https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1   2.786551            2.670592              1.917763           AND            01    1.0          0.136698
# 23   https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1   2.786551            2.670592              1.917763           AND            01    1.5          0.205047
# 24   https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1   2.786551            2.670592              1.917763           AND            01    2.0          0.273397
# 25   https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1   2.665480            2.690192              0.921844           AND            10    0.1          0.012488
# 26   https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1   2.665480            2.690192              0.921844           AND            10    0.5          0.062442
# 27   https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1   2.665480            2.690192              0.921844           AND            10    1.0          0.124884
# 28   https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1   2.665480            2.690192              0.921844           AND            10    1.5          0.187327
# 29   https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1   2.665480            2.690192              0.921844           AND            10    2.0          0.249769
# ..                                                 ...        ...                 ...                   ...           ...            ..    ...               ...
# 90   https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1   3.623880            3.836611              1.846550           XNOR           01    0.1          0.021650
# 91   https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1   3.623880            3.836611              1.846550           XNOR           01    0.5          0.108249
# 92   https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1   3.623880            3.836611              1.846550           XNOR           01    1.0          0.216497
# 93   https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1   3.623880            3.836611              1.846550           XNOR           01    1.5          0.324746
# 94   https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1   3.623880            3.836611              1.846550           XNOR           01    2.0          0.432995
# 95   https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1   4.473730            4.085444              3.106148           NOR            00    0.1          0.028953
# 96   https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1   4.473730            4.085444              3.106148           NOR            00    0.5          0.144765
# 97   https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1   4.473730            4.085444              3.106148           NOR            00    1.0          0.289530
# 98   https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1   4.473730            4.085444              3.106148           NOR            00    1.5          0.434295
# 99   https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1   4.473730            4.085444              3.106148           NOR            00    2.0          0.579059
# 100  https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1   4.030526            4.118991              1.265762           NOR            01    0.1          0.025264
# 101  https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1   4.030526            4.118991              1.265762           NOR            01    0.5          0.126319
# 102  https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1   4.030526            4.118991              1.265762           NOR            01    1.0          0.252639
# 103  https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1   4.030526            4.118991              1.265762           NOR            01    1.5          0.378958
# 104  https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1   4.030526            4.118991              1.265762           NOR            01    2.0          0.505277
# 105  https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1   4.849398            4.147481              2.026115           OR             11    0.1          0.031871
# 106  https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1   4.849398            4.147481              2.026115           OR             11    0.5          0.159354
# 107  https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1   4.849398            4.147481              2.026115           OR             11    1.0          0.318709
# 108  https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1   4.849398            4.147481              2.026115           OR             11    1.5          0.478063
# 109  https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1   4.849398            4.147481              2.026115           OR             11    2.0          0.637418
# 110  https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1   4.068193            4.710491              1.527484           AND            00    0.1          0.025588
# 111  https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1   4.068193            4.710491              1.527484           AND            00    0.5          0.127939
# 112  https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1   4.068193            4.710491              1.527484           AND            00    1.0          0.255877
# 113  https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1   4.068193            4.710491              1.527484           AND            00    1.5          0.383816
# 114  https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1   4.068193            4.710491              1.527484           AND            00    2.0          0.511755
# 115  https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1  4.616430            4.947402              1.219633           XOR            01    0.1          0.030084
# 116  https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1  4.616430            4.947402              1.219633           XOR            01    0.5          0.150419
# 117  https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1  4.616430            4.947402              1.219633           XOR            01    1.0          0.300838
# 118  https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1  4.616430            4.947402              1.219633           XOR            01    1.5          0.451257
# 119  https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1  4.616430            4.947402              1.219633           XOR            01    2.0          0.601676
#
# [120 rows x 8 columns]

# %%
exps = {}
for t in targets:
    exps[t] = {}
    dft = doubling_target.loc[doubling_target['post_od_raw'] == t]
    for i, row in dft[['SynBioHub URI', 'od']].iterrows():
        exps[t][row['SynBioHub URI']] = str(row['od'])
exps
# Out:
# {0.1: {'https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1': '0.008359737323932921',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1': '0.011414834119839116',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1': '0.012414506864561132',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1': '0.009022351839200674',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1': '0.013669829510818287',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1': '0.012488437454262835',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5993/1': '0.0102981236211462',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16967/1': '0.01222500163772367',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8545/1': '0.012462667248668824',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7374/1': '0.012501113310296024',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16968/1': '0.015483735074422448',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8543/1': '0.01653200994368021',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7299/1': '0.016749082502431425',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7300/1': '0.013992874987829414',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16970/1': '0.017749889930966923',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6391/1': '0.020815757697072463',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8542/1': '0.01855763273599867',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6389/1': '0.02352260462528088',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1': '0.021649734750598403',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1': '0.028952968621350862',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1': '0.02526386607151973',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1': '0.031870881923507496',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1': '0.02558774522227959',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1': '0.03008381261121042'},
#  0.5: {'https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1': '0.041798686619664606',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1': '0.05707417059919558',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1': '0.062072534322805656',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1': '0.04511175919600336',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1': '0.06834914755409142',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1': '0.062442187271314176',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5993/1': '0.051490618105730995',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16967/1': '0.061125008188618345',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8545/1': '0.06231333624334411',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7374/1': '0.06250556655148012',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16968/1': '0.07741867537211224',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8543/1': '0.08266004971840105',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7299/1': '0.08374541251215711',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7300/1': '0.06996437493914706',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16970/1': '0.08874944965483461',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6391/1': '0.10407878848536231',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8542/1': '0.09278816367999335',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6389/1': '0.1176130231264044',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1': '0.108248673752992',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1': '0.1447648431067543',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1': '0.12631933035759862',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1': '0.1593544096175375',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1': '0.12793872611139795',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1': '0.1504190630560521'},
#  1.0: {'https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1': '0.08359737323932921',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1': '0.11414834119839116',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1': '0.12414506864561131',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1': '0.09022351839200672',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1': '0.13669829510818285',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1': '0.12488437454262835',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5993/1': '0.10298123621146199',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16967/1': '0.12225001637723669',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8545/1': '0.12462667248668823',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7374/1': '0.12501113310296025',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16968/1': '0.15483735074422447',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8543/1': '0.1653200994368021',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7299/1': '0.16749082502431423',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7300/1': '0.13992874987829412',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16970/1': '0.17749889930966922',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6391/1': '0.20815757697072462',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8542/1': '0.1855763273599867',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6389/1': '0.2352260462528088',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1': '0.216497347505984',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1': '0.2895296862135086',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1': '0.25263866071519725',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1': '0.318708819235075',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1': '0.2558774522227959',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1': '0.3008381261121042'},
#  1.5: {'https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1': '0.12539605985899382',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1': '0.17122251179758674',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1': '0.18621760296841697',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1': '0.1353352775880101',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1': '0.2050474426622743',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1': '0.18732656181394253',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5993/1': '0.15447185431719299',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16967/1': '0.18337502456585503',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8545/1': '0.18694000873003236',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7374/1': '0.18751669965444037',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16968/1': '0.2322560261163367',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8543/1': '0.24798014915520314',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7299/1': '0.25123623753647134',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7300/1': '0.20989312481744118',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16970/1': '0.26624834896450383',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6391/1': '0.31223636545608696',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8542/1': '0.27836449103998007',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6389/1': '0.35283906937921317',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1': '0.324746021258976',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1': '0.4342945293202629',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1': '0.37895799107279593',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1': '0.4780632288526125',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1': '0.3838161783341938',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1': '0.45125718916815627'},
#  2.0: {'https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1': '0.16719474647865842',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1': '0.22829668239678233',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1': '0.24829013729122262',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1': '0.18044703678401344',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1': '0.2733965902163657',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1': '0.2497687490852567',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5993/1': '0.20596247242292398',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16967/1': '0.24450003275447338',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8545/1': '0.24925334497337645',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7374/1': '0.2500222662059205',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16968/1': '0.30967470148844894',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8543/1': '0.3306401988736042',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7299/1': '0.33498165004862845',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7300/1': '0.27985749975658825',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16970/1': '0.35499779861933844',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6391/1': '0.41631515394144925',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8542/1': '0.3711526547199734',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6389/1': '0.4704520925056176',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1': '0.432994695011968',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1': '0.5790593724270172',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1': '0.5052773214303945',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1': '0.63741763847015',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1': '0.5117549044455918',
#   'https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1': '0.6016762522242084'}}

# %%
doubling_variance
# Out:
#                                          SynBioHub URI  doubling_time_mean  doubling_time_median  doubling_time_std strain_circuit input
# 22  https://hub.sd2e.org/user/sd2e/design/UWBF_8544/1   2.234388            2.231629              0.575075           NAND           00
# 18  https://hub.sd2e.org/user/sd2e/design/UWBF_8225/1   2.555079            2.459933              0.969249           OR             00
# 4   https://hub.sd2e.org/user/sd2e/design/UWBF_5783/1   2.657895            2.631736              0.582340           OR             10
# 17  https://hub.sd2e.org/user/sd2e/design/UWBF_7377/1   2.305241            2.665238              0.736464           XNOR           10
# 15  https://hub.sd2e.org/user/sd2e/design/UWBF_7375/1   2.786551            2.670592              1.917763           AND            01
# 13  https://hub.sd2e.org/user/sd2e/design/UWBF_7373/1   2.665480            2.690192              0.921844           AND            10
# 6   https://hub.sd2e.org/user/sd2e/design/UWBF_5993/1   2.439362            2.691017              0.658425           OR             01
# 0   https://hub.sd2e.org/user/sd2e/design/UWBF_16967/1  2.638441            2.747754              0.570717           XOR            11
# 23  https://hub.sd2e.org/user/sd2e/design/UWBF_8545/1   2.662836            2.799590              0.668490           NAND           01
# 14  https://hub.sd2e.org/user/sd2e/design/UWBF_7374/1   2.666781            2.884659              0.678430           AND            11
# 1   https://hub.sd2e.org/user/sd2e/design/UWBF_16968/1  2.972680            3.054309              1.043551           XOR            10
# 21  https://hub.sd2e.org/user/sd2e/design/UWBF_8543/1   3.080874            3.105278              0.804857           NAND           10
# 11  https://hub.sd2e.org/user/sd2e/design/UWBF_7299/1   3.103366            3.106904              0.658883           XNOR           11
# 12  https://hub.sd2e.org/user/sd2e/design/UWBF_7300/1   2.819646            3.119151              0.699277           XNOR           00
# 3   https://hub.sd2e.org/user/sd2e/design/UWBF_16970/1  3.207547            3.382119              0.600113           XOR            00
# 10  https://hub.sd2e.org/user/sd2e/design/UWBF_6391/1   3.533176            3.406196              2.384667           NOR            11
# 20  https://hub.sd2e.org/user/sd2e/design/UWBF_8542/1   3.292296            3.420036              0.484531           NAND           11
# 8   https://hub.sd2e.org/user/sd2e/design/UWBF_6389/1   3.831637            3.590930              2.180337           NOR            10
# 19  https://hub.sd2e.org/user/sd2e/design/UWBF_8231/1   3.623880            3.836611              1.846550           XNOR           01
# 9   https://hub.sd2e.org/user/sd2e/design/UWBF_6390/1   4.473730            4.085444              3.106148           NOR            00
# 7   https://hub.sd2e.org/user/sd2e/design/UWBF_6388/1   4.030526            4.118991              1.265762           NOR            01
# 5   https://hub.sd2e.org/user/sd2e/design/UWBF_5992/1   4.849398            4.147481              2.026115           OR             11
# 16  https://hub.sd2e.org/user/sd2e/design/UWBF_7376/1   4.068193            4.710491              1.527484           AND            00
# 2   https://hub.sd2e.org/user/sd2e/design/UWBF_16969/1  4.616430            4.947402              1.219633           XOR            01

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np


predictions=doubling_target

strains = df1['SynBioHub URI'].unique()
data=df1.loc[df1['inc_time_2'] == '8:hour']


for target in targets:
    plt.axhline(target)
    
for strain in strains:
    p = data.loc[data['SynBioHub URI'] == strain]
    p = p.sort_values(['od'], ascending=True)
    plt.plot(p['od'], p['post_od_raw'], label=strain,alpha=0.1);


    s = predictions.loc[(predictions['SynBioHub URI'] == strain)  ]
    s = s.sort_values(['post_od_raw'], ascending=True)
    plt.plot(s['od'], s['post_od_raw'], label=None,  marker='x', alpha=0.5);

    
    
    #plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Inoculation OD")
plt.ylabel("Post OD")
plt.title(str(duration) + "h Inoculations and Target Post OD")
# Out:
# Text(0.5, 1.0, '8:hourh Inoculations and Target Post OD')
